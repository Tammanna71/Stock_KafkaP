# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
pip install s3fs
# Out:
# Requirement already satisfied: s3fs in d:\anaconda\lib\site-packages (2024.6.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in d:\anaconda\lib\site-packages (from s3fs) (2.12.3)
# Requirement already satisfied: fsspec==2024.6.1.* in d:\anaconda\lib\site-packages (from s3fs) (2024.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\anaconda\lib\site-packages (from s3fs) (3.10.5)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in d:\anaconda\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.69)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in d:\anaconda\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in d:\anaconda\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.11.0)
# Requirement already satisfied: typing_extensions>=3.7 in d:\anaconda\lib\site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (4.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\anaconda\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\anaconda\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\anaconda\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.3)
# Requirement already satisfied: idna>=2.0 in d:\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
consumer = KafkaConsumer(
    'demo_test',
    bootstrap_servers=['13.127.52.95:9092'],
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
s3 = S3FileSystem()

# %%
# for c in consumer:
#     print(c.value)

# %%
for count, i in enumerate(consumer):
    print(count)
    print(i.value)
# Out:
# 0
# {'Date': '2014-04-09', 'Open': 328.470001, 'High': 332.179993, 'Low': 322.5, 'Close': 331.809998, 'Adj Close': 331.809998, 'Volume': 5056600}
# 1
# {'Date': '2013-04-17', 'Open': 270.799988, 'High': 270.850006, 'Low': 264.25, 'Close': 267.399994, 'Adj Close': 267.399994, 'Volume': 3135100}
# 2
# {'Date': '2004-05-20', 'Open': 41.650002, 'High': 41.970001, 'Low': 40.799999, 'Close': 40.98, 'Adj Close': 40.98, 'Volume': 5926300}
# 3
# {'Date': '2020-10-13', 'Open': 3467.98999, 'High': 3492.379883, 'Low': 3424.219971, 'Close': 3443.629883, 'Adj Close': 3443.629883, 'Volume': 5744700}
# 4
# {'Date': '2002-05-01', 'Open': 16.549999, 'High': 17.049999, 'Low': 16.42, 'Close': 16.49, 'Adj Close': 16.49, 'Volume': 7701300}
# 5
# {'Date': '2001-06-14', 'Open': 14.12, 'High': 14.12, 'Low': 13.16, 'Close': 13.29, 'Adj Close': 13.29, 'Volume': 5088300}
# 6
# {'Date': '1998-11-02', 'Open': 21.354168, 'High': 21.90625, 'Low': 20.75, 'Close': 21.833332, 'Adj Close': 21.833332, 'Volume': 31494000}
# 7
# {'Date': '2016-08-15', 'Open': 771.900024, 'High': 772.039978, 'Low': 767.710022, 'Close': 768.48999, 'Adj Close': 768.48999, 'Volume': 2118500}
# 8
# {'Date': '2008-12-16', 'Open': 49.619999, 'High': 52.959999, 'Low': 49.290001, 'Close': 52.630001, 'Adj Close': 52.630001, 'Volume': 8862900}
# 9
# {'Date': '2013-06-06', 'Open': 267.75, 'High': 270.5, 'Low': 264.209991, 'Close': 267.829987, 'Adj Close': 267.829987, 'Volume': 2476300}
# 10
# {'Date': '2004-11-08', 'Open': 36.75, 'High': 37.580002, 'Low': 36.720001, 'Close': 37.32, 'Adj Close': 37.32, 'Volume': 6886500}
# 11
# {'Date': '2015-06-10', 'Open': 426.459991, 'High': 432.200012, 'Low': 425.660004, 'Close': 430.769989, 'Adj Close': 430.769989, 'Volume': 2172300}
# 12
# {'Date': '2009-11-09', 'Open': 127.110001, 'High': 128.320007, 'Low': 125.589996, 'Close': 126.669998, 'Adj Close': 126.669998, 'Volume': 8624200}
# 13
# {'Date': '1999-03-22', 'Open': 66.59375, 'High': 68.25, 'Low': 65.25, 'Close': 66.0, 'Adj Close': 66.0, 'Volume': 6598400}
# 14
# {'Date': '2015-05-05', 'Open': 422.850006, 'High': 427.51001, 'Low': 421.019989, 'Close': 421.190002, 'Adj Close': 421.190002, 'Volume': 2856400}
# 15
# {'Date': '2005-01-28', 'Open': 42.09, 'High': 43.0, 'Low': 41.529999, 'Close': 42.220001, 'Adj Close': 42.220001, 'Volume': 6152400}
# 16
# {'Date': '2009-04-16', 'Open': 75.330002, 'High': 77.480003, 'Low': 75.160004, 'Close': 77.25, 'Adj Close': 77.25, 'Volume': 7467800}
# 17
# {'Date': '2019-05-29', 'Open': 1823.119995, 'High': 1830.0, 'Low': 1807.530029, 'Close': 1819.189941, 'Adj Close': 1819.189941, 'Volume': 4279000}
# 18
# {'Date': '2007-12-21', 'Open': 91.470001, 'High': 92.279999, 'Low': 90.389999, 'Close': 91.260002, 'Adj Close': 91.260002, 'Volume': 6604900}
# 19
# {'Date': '2001-09-26', 'Open': 7.2, 'High': 7.23, 'Low': 6.0, 'Close': 6.35, 'Adj Close': 6.35, 'Volume': 7839100}
# 20
# {'Date': '1998-10-09', 'Open': 15.041667, 'High': 15.3125, 'Low': 13.958333, 'Close': 15.197917, 'Adj Close': 15.197917, 'Volume': 20727000}
# 21
# {'Date': '2012-02-01', 'Open': 173.809998, 'High': 179.949997, 'Low': 172.0, 'Close': 179.460007, 'Adj Close': 179.460007, 'Volume': 21336600}
# 22
# {'Date': '2000-10-11', 'Open': 27.9375, 'High': 30.25, 'Low': 27.625, 'Close': 27.8125, 'Adj Close': 27.8125, 'Volume': 7889700}
# 23
# {'Date': '2004-04-27', 'Open': 47.59, 'High': 48.799999, 'Low': 46.790001, 'Close': 48.0, 'Adj Close': 48.0, 'Volume': 8983700}
# 24
# {'Date': '2020-08-27', 'Open': 3450.050049, 'High': 3453.0, 'Low': 3378.0, 'Close': 3400.0, 'Adj Close': 3400.0, 'Volume': 4264800}
# 25
# {'Date': '2020-12-30', 'Open': 3341.0, 'High': 3342.100098, 'Low': 3282.469971, 'Close': 3285.850098, 'Adj Close': 3285.850098, 'Volume': 3209300}
# 26
# {'Date': '2004-12-07', 'Open': 39.450001, 'High': 39.75, 'Low': 38.049999, 'Close': 38.200001, 'Adj Close': 38.200001, 'Volume': 7093400}
# 27
# {'Date': '2003-10-31', 'Open': 55.900002, 'High': 56.130001, 'Low': 54.380001, 'Close': 54.43, 'Adj Close': 54.43, 'Volume': 7726700}
# 28
# {'Date': '2007-06-29', 'Open': 69.029999, 'High': 69.190002, 'Low': 68.150002, 'Close': 68.410004, 'Adj Close': 68.410004, 'Volume': 5316600}
# 29
# {'Date': '2001-05-31', 'Open': 15.84, 'High': 17.200001, 'Low': 15.75, 'Close': 16.690001, 'Adj Close': 16.690001, 'Volume': 9632000}
# 30
# {'Date': '2015-03-10', 'Open': 377.450012, 'High': 377.769989, 'Low': 369.179993, 'Close': 369.51001, 'Adj Close': 369.51001, 'Volume': 3121000}
# 31
# {'Date': '1999-05-11', 'Open': 75.34375, 'High': 76.9375, 'Low': 72.0, 'Close': 74.1875, 'Adj Close': 74.1875, 'Volume': 13941400}
# 32
# {'Date': '2018-11-13', 'Open': 1649.290039, 'High': 1677.060059, 'Low': 1613.75, 'Close': 1631.170044, 'Adj Close': 1631.170044, 'Volume': 5933300}
# 33
# {'Date': '2017-06-29', 'Open': 979.0, 'High': 987.559998, 'Low': 965.25, 'Close': 975.929993, 'Adj Close': 975.929993, 'Volume': 4303000}
# 34
# {'Date': '2009-12-16', 'Open': 130.929993, 'High': 131.449997, 'Low': 127.650002, 'Close': 128.360001, 'Adj Close': 128.360001, 'Volume': 10261300}
# 35
# {'Date': '1997-06-10', 'Open': 1.708333, 'High': 1.708333, 'Low': 1.53125, 'Close': 1.583333, 'Adj Close': 1.583333, 'Volume': 5458800}
# 36
# {'Date': '2008-12-30', 'Open': 49.509998, 'High': 51.209999, 'Low': 48.740002, 'Close': 50.759998, 'Adj Close': 50.759998, 'Volume': 6601300}
# 37
# {'Date': '2010-01-21', 'Open': 127.260002, 'High': 128.149994, 'Low': 125.0, 'Close': 126.620003, 'Adj Close': 126.620003, 'Volume': 9970600}
# 38
# {'Date': '2009-01-14', 'Open': 50.099998, 'High': 50.099998, 'Low': 48.139999, 'Close': 48.490002, 'Adj Close': 48.490002, 'Volume': 10442600}
# 39
# {'Date': '2011-02-02', 'Open': 171.419998, 'High': 175.199997, 'Low': 170.869995, 'Close': 173.529999, 'Adj Close': 173.529999, 'Volume': 4547500}
# 40
# {'Date': '2007-03-22', 'Open': 39.48, 'High': 39.720001, 'Low': 38.91, 'Close': 39.490002, 'Adj Close': 39.490002, 'Volume': 5331500}
# 41
# {'Date': '1999-11-23', 'Open': 80.375, 'High': 85.625, 'Low': 76.25, 'Close': 81.75, 'Adj Close': 81.75, 'Volume': 18332500}
# 42
# {'Date': '2000-09-27', 'Open': 38.6875, 'High': 39.625, 'Low': 35.5, 'Close': 37.875, 'Adj Close': 37.875, 'Volume': 10030900}
# 43
# {'Date': '2004-09-01', 'Open': 38.23, 'High': 39.009998, 'Low': 38.02, 'Close': 38.240002, 'Adj Close': 38.240002, 'Volume': 5252500}
# 44
# {'Date': '2001-12-28', 'Open': 10.91, 'High': 11.08, 'Low': 10.69, 'Close': 10.9, 'Adj Close': 10.9, 'Volume': 10257900}
# 45
# {'Date': '2016-03-03', 'Open': 577.960022, 'High': 579.869995, 'Low': 573.109985, 'Close': 577.48999, 'Adj Close': 577.48999, 'Volume': 2741300}
# 46
# {'Date': '2010-10-05', 'Open': 157.080002, 'High': 161.210007, 'Low': 157.009995, 'Close': 160.869995, 'Adj Close': 160.869995, 'Volume': 5620000}
# 47
# {'Date': '2009-09-23', 'Open': 92.82, 'High': 94.5, 'Low': 92.220001, 'Close': 92.379997, 'Adj Close': 92.379997, 'Volume': 5685300}
# 48
# {'Date': '2016-04-18', 'Open': 625.349976, 'High': 637.640015, 'Low': 624.960022, 'Close': 635.349976, 'Adj Close': 635.349976, 'Volume': 4360900}
# 49
# {'Date': '2004-09-13', 'Open': 39.130001, 'High': 40.040001, 'Low': 38.82, 'Close': 40.009998, 'Adj Close': 40.009998, 'Volume': 8065200}
# 50
# {'Date': '2002-08-05', 'Open': 13.65, 'High': 13.79, 'Low': 12.78, 'Close': 12.87, 'Adj Close': 12.87, 'Volume': 3857300}
# 51
# {'Date': '2008-01-03', 'Open': 96.059998, 'High': 97.25, 'Low': 94.519997, 'Close': 95.209999, 'Adj Close': 95.209999, 'Volume': 9122500}
# 52
# {'Date': '2005-11-29', 'Open': 48.310001, 'High': 49.43, 'Low': 48.119999, 'Close': 48.549999, 'Adj Close': 48.549999, 'Volume': 10384400}
# 53
# {'Date': '1998-10-15', 'Open': 15.708333, 'High': 16.3125, 'Low': 15.416667, 'Close': 16.177082, 'Adj Close': 16.177082, 'Volume': 16971000}
# 54
# {'Date': '2005-01-18', 'Open': 44.290001, 'High': 45.0, 'Low': 44.150002, 'Close': 44.580002, 'Adj Close': 44.580002, 'Volume': 7131600}
# 55
# {'Date': '2009-01-16', 'Open': 51.799999, 'High': 52.330002, 'Low': 49.529999, 'Close': 51.59, 'Adj Close': 51.59, 'Volume': 8258200}
# 56
# {'Date': '2011-01-18', 'Open': 188.660004, 'High': 191.600006, 'Low': 188.25, 'Close': 191.25, 'Adj Close': 191.25, 'Volume': 3896200}
# 57
# {'Date': '2006-10-16', 'Open': 32.849998, 'High': 33.200001, 'Low': 32.549999, 'Close': 32.599998, 'Adj Close': 32.599998, 'Volume': 6769400}
# 58
# {'Date': '2008-08-15', 'Open': 88.279999, 'High': 89.529999, 'Low': 86.260002, 'Close': 86.400002, 'Adj Close': 86.400002, 'Volume': 6871600}
# 59
# {'Date': '2013-08-14', 'Open': 294.290009, 'High': 294.290009, 'Low': 290.540009, 'Close': 291.339996, 'Adj Close': 291.339996, 'Volume': 1415000}
# 60
# {'Date': '2007-07-20', 'Open': 72.620003, 'High': 72.959999, 'Low': 70.5, 'Close': 71.629997, 'Adj Close': 71.629997, 'Volume': 9130700}
# 61
# {'Date': '2010-10-07', 'Open': 156.509995, 'High': 157.399994, 'Low': 153.389999, 'Close': 156.270004, 'Adj Close': 156.270004, 'Volume': 4622000}
# 62
# {'Date': '2005-02-28', 'Open': 34.720001, 'High': 35.66, 'Low': 34.669998, 'Close': 35.18, 'Adj Close': 35.18, 'Volume': 8422900}
# 63
# {'Date': '2008-06-02', 'Open': 81.150002, 'High': 81.57, 'Low': 80.050003, 'Close': 80.230003, 'Adj Close': 80.230003, 'Volume': 6215200}
# 64
# {'Date': '2010-09-03', 'Open': 136.889999, 'High': 139.5, 'Low': 136.630005, 'Close': 138.789993, 'Adj Close': 138.789993, 'Volume': 6581200}
# 65
# {'Date': '2006-12-14', 'Open': 38.740002, 'High': 39.540001, 'Low': 38.599998, 'Close': 39.02, 'Adj Close': 39.02, 'Volume': 6296100}
# 66
# {'Date': '1998-04-16', 'Open': 8.010417, 'High': 8.276042, 'Low': 7.765625, 'Close': 8.208333, 'Adj Close': 8.208333, 'Volume': 16244400}
# 67
# {'Date': '2010-03-08', 'Open': 128.300003, 'High': 130.850006, 'Low': 127.709999, 'Close': 130.110001, 'Adj Close': 130.110001, 'Volume': 5605900}
# 68
# {'Date': '2012-12-28', 'Open': 245.850006, 'High': 247.440002, 'Low': 245.050003, 'Close': 245.179993, 'Adj Close': 245.179993, 'Volume': 1858700}
# 69
# {'Date': '2006-04-11', 'Open': 36.610001, 'High': 36.75, 'Low': 35.52, 'Close': 36.060001, 'Adj Close': 36.060001, 'Volume': 6605600}
# 70
# {'Date': '2001-10-05', 'Open': 6.97, 'High': 7.9, 'Low': 6.74, 'Close': 7.2, 'Adj Close': 7.2, 'Volume': 5900900}
# 71
# {'Date': '1998-01-13', 'Open': 4.34375, 'High': 4.666667, 'Low': 4.322917, 'Close': 4.645833, 'Adj Close': 4.645833, 'Volume': 7321200}
# 72
# {'Date': '2017-01-27', 'Open': 839.0, 'High': 839.700012, 'Low': 829.440002, 'Close': 835.77002, 'Adj Close': 835.77002, 'Volume': 2998700}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     print(count)
#       3     print(i.value)
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File D:\anaconda\Lib\site-packages\kafka\client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File D:\anaconda\Lib\site-packages\kafka\client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File D:\anaconda\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File D:\anaconda\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-project-tamanna/stock_market_amazon_{}.json".format(count), 'w') as file:
         json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-project-tamanna/stock_market_amazon_{}.json".format(count), 'w') as file:
#       3          json.dump(i.value, file)
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File D:\anaconda\Lib\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File D:\anaconda\Lib\site-packages\kafka\client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File D:\anaconda\Lib\site-packages\kafka\client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File D:\anaconda\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File D:\anaconda\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
